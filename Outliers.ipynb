# %%
pip install pandas
pip install seaborn
pip install matplotilib
pip install numpy
pip install scipy
# Out:
#   File "<ipython-input-2-b7c90889724b>", line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import iqr
import numpy as np
#from pandas_profiling import ProfileReport
import scipy.stats as stats

# %%
df = pd.read_csv('houses_data.csv',parse_dates = ['Date'])
df.drop('Date', axis=1, inplace=True)

# %%
df_nums = df.select_dtypes(["int","int64", "float"])
df_test = df_nums.copy()
df_test
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %% [markdown]
# ### Counting outliers

# %%
Q1 = df_nums.quantile(0.25)
Q3 = df_nums.quantile(0.75)
IQR = Q3 - Q1

# %%
((df_nums < (Q1 - 1.5 * IQR)) | (df_nums > (Q3 + 1.5 * IQR))).sum()
# Out:
# Rooms            682
# Price            612
# Distance         411
# Postcode         208
# Bedroom2         655
# Bathroom         143
# Car              644
# Landsize         368
# BuildingArea     353
# YearBuilt          6
# Lattitude        262
# Longtitude       408
# Propertycount    359
# dtype: int64

# %%
for column in df_test.columns:
    sns.boxplot(x=df_nums[column])
    plt.show()

# %% [markdown]
# #####  Sigma

# %%
Q1 = df_test_sigma.quantile(0.25)
Q3 = df_test_sigma.quantile(0.75)
IQR = Q3 - Q1

# %%
((df_test_sigma < (Q1 - 1.5 * IQR)) | (df_test_sigma > (Q3 + 1.5 * IQR))).sum()
# Out:
# Rooms            596
# Price            446
# Distance         236
# Postcode          46
# Bedroom2         556
# Bathroom           0
# Car              506
# Landsize         344
# BuildingArea     349
# YearBuilt          0
# Lattitude        134
# Longtitude       256
# Propertycount     86
# dtype: int64

# %%
for column in df_test.columns:
    sns.boxplot(x=df_test_sigma[column])
    plt.show()

# %% [markdown]
# ##### IQR

# %%
Q1 = df_test_IQR.quantile(0.25)
Q3 = df_test_IQR.quantile(0.75)
IQR = Q3 - Q1

# %%
((df_test_IQR < (Q1 - 1.5 * IQR)) | (df_test_IQR > (Q3 + 1.5 * IQR))).sum()
# Out:
# Rooms              0
# Price            127
# Distance          83
# Postcode           0
# Bedroom2           0
# Bathroom           0
# Car                0
# Landsize           4
# BuildingArea     119
# YearBuilt          0
# Lattitude         23
# Longtitude        54
# Propertycount     86
# dtype: int64

# %%
for column in df_test_IQR.columns:
    sns.boxplot(x=df_test_IQR[column])
    plt.show()

# %% [markdown]
# ##### Modified-Z score

# %%
Q1 = df_test_z.quantile(0.25)
Q3 = df_test_z.quantile(0.75)
IQR = Q3 - Q1

# %%
((df_test_z < (Q1 - 1.5 * IQR)) | (df_test_z > (Q3 + 1.5 * IQR))).sum()
# Out:
# Rooms            663
# Price            506
# Distance         278
# Postcode          46
# Bedroom2         635
# Bathroom         106
# Car              569
# Landsize         202
# BuildingArea     309
# YearBuilt          5
# Lattitude        216
# Longtitude       356
# Propertycount    359
# dtype: int64

# %%
for column in df_test_z.columns:
    sns.boxplot(x=df_test_z[column])
    plt.show()

# %% [markdown]
# #### Log

# %%
Q1 = df_test_log.quantile(0.25)
Q3 = df_test_log.quantile(0.75)
IQR = Q3 - Q1

# %%
((df_test_log < (Q1 - 1.5 * IQR)) | (df_test_log > (Q3 + 1.5 * IQR))).sum()
# Out:
# Rooms              681
# Price                0
# Distance             0
# Postcode         13580
# Bedroom2           691
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea         0
# YearBuilt         8205
# Lattitude            0
# Longtitude       13580
# Propertycount        0
# dtype: int64

# %%
for column in df_test_z.columns:
    sns.boxplot(x=df_test_z[column])
    plt.show()

# %% [markdown]
# ### Creating charts and stats for outliers

# %%
num_columns =['Distance','Longtitude','Lattitude','Landsize','Price']

# %%
for column in df_test.columns:
    sns.boxplot(x=df[column])
    sns.displot(x=df[column])
    print(df[column].describe()[['25%','75%','std']])
    print(f'IQR for {column} is:{iqr(df[column])}')
    
    plt.show()
# Out:
# 25%    2.000000
# 75%    3.000000
# std    0.955748
# Name: Rooms, dtype: float64
# IQR for Rooms is:1.0
# 25%    6.500000e+05
# 75%    1.330000e+06
# std    6.393107e+05
# Name: Price, dtype: float64
# IQR for Price is:680000.0
# 25%     6.100000
# 75%    13.000000
# std     5.868725
# Name: Distance, dtype: float64
# IQR for Distance is:6.9
# 25%    3044.000000
# 75%    3148.000000
# std      90.676964
# Name: Postcode, dtype: float64
# IQR for Postcode is:104.0
# 25%    2.000000
# 75%    3.000000
# std    0.965921
# Name: Bedroom2, dtype: float64
# IQR for Bedroom2 is:1.0
# 25%    1.000000
# 75%    2.000000
# std    0.691712
# Name: Bathroom, dtype: float64
# IQR for Bathroom is:1.0
# 25%    1.000000
# 75%    2.000000
# std    0.962634
# Name: Car, dtype: float64
# IQR for Car is:nan
# 25%     177.000000
# 75%     651.000000
# std    3990.669241
# Name: Landsize, dtype: float64
# IQR for Landsize is:474.0
# 25%     93.000000
# 75%    174.000000
# std    541.014538
# ...

# %% [markdown]
# ### Log

# %%
def logs(column):
    column = column.replace(0, np.nan)
    return np.log(column)

# %%
df_test_log = df_test.apply(lambda x: logs(x))
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Sigmas

# %%
def sigma(column):
    sigma = column.std()*3
    sigma_minus = column.mean() - sigma
    sigma_plus = column.mean() + sigma
    
    return (column>= sigma_minus) & (column <= sigma_plus)

# %%
df_test_sigma=df_test[df_test.apply(lambda x: sigma(x))]

# %% [markdown]
# ### IQR

# %%
def IQR_outliner(column):
    Q1_test=column.quantile(0.25)
    Q3_test=column.quantile(0.75)
    IQR_test = IQR_test=Q3_test-Q1_test
    lower_whisker = Q1_test - 1.5*IQR_test
    upper_whisker = Q3_test+1.5*IQR_test
    return (column > lower_whisker) & (column < upper_whisker)

# %%
df_test_IQR = df_test[df_test.apply(lambda x: IQR_outliner(x))]

# %% [markdown]
# ### Z-score

# %%
df_test.apply(stats.zscore)
# Out:
#           Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0     -0.981463  0.632448 -1.301485 -0.422415 -0.947035 -0.772376  NaN
# 1     -0.981463 -0.063640 -1.301485 -0.422415 -0.947035 -0.772376  NaN
# 2      0.064876  0.608984 -1.301485 -0.422415  0.088284  0.673367  NaN
# 3      0.064876 -0.353025 -1.301485 -0.422415  0.088284  0.673367  NaN
# 4      1.111216  0.820157 -1.301485 -0.422415  0.088284 -0.772376  NaN
# ...         ...       ...       ...       ...       ...       ...  ...
# 13575  1.111216  0.264851  1.118210  0.492956  1.123604  0.673367  NaN
# 13576  0.064876 -0.069897 -0.568761 -0.984872  0.088284  0.673367  NaN
# 13577  0.064876  0.147533 -0.568761 -0.984872  0.088284  0.673367  NaN
# 13578  1.111216  2.227975 -0.568761 -0.984872  1.123604 -0.772376  NaN
# 13579  1.111216  0.327421 -0.653961 -1.017958  1.123604 -0.772376  NaN
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# ...

# %%
def mod_z(column):
    thresh = 3.5
    MAD = column.mad()
    nominator = column.apply(lambda x: x - column.median())
    z_score = 0.6745*nominator/MAD
    z_score = z_score[(np.abs(z_score)) < thresh]
    return np.abs(z_score)

# %%
df_z = df_test.apply(lambda x: mod_z(x))
df_test_z = df_test[df_z >= 0]
